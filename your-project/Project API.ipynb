# %%
import requests

api_key = "AIzaSyAgnqAeOUBm47F9-blDN1znlMy_8vOmIPs"
book_title = "El imperio final"

# Replace spaces in the title with '+' for the query
query_title = book_title.replace(' ', '+')

url = f"https://www.googleapis.com/books/v1/volumes?q=intitle:{query_title}&key={api_key}"

response = requests.get(url)
data = response.json()

if 'items' in data:
    book_info = data['items'][0]['volumeInfo']
    title = book_info.get('title', 'Title not available')
    authors = ', '.join(book_info.get('authors', ['Author not available']))
    description = book_info.get('description', 'Description not available')

    print(f"Title: {title}")
    print(f"Authors: {authors}")
    print(f"Description: {description}")
else:
    print("Book information not found.")
# Out:
# Title: El Imperio Final (Nacidos de la Bruma-Mistborn [edición ilustrada] 1)
# Authors: Brandon Sanderson
# ...

# %%
def get_book_recommendations(genre, pages, age):
    api_key = "AIzaSyAgnqAeOUBm47F9-blDN1znlMy_8vOmIPs"

    # Replace spaces in the genre with '+' for the query
    query_genre = genre.replace(' ', '+')

    # Construct the API request URL
    url = f"https://www.googleapis.com/books/v1/volumes?q=subject:{query_genre}&maxResults=5&key={api_key}"

    # Additional parameters can be added based on user preferences, e.g., filter by page count, etc.

    # Make the API request
    response = requests.get(url)
    data = response.json()

    if 'items' in data:
        recommendations = []
        for item in data['items']:
            book_info = item['volumeInfo']
            title = book_info.get('title', 'Title not available')
            authors = ', '.join(book_info.get('authors', ['Author not available']))
            description = book_info.get('description', 'Description not available')

            recommendations.append({
                'Title': title,
                'Authors': authors,
                'Description': description
            })

        return recommendations
    else:
        return None

# Ask the user for input
genre = input("Which genre do you like to read? ")
pages = input("How many pages long are usually the books that you read? ")
age = input("How old are you? ")

# Get recommendations based on user input
recommendations = get_book_recommendations(genre, pages, age)

# Display recommendations
if recommendations:
    print("\nHere are some book recommendations for you:")
    for i, book in enumerate(recommendations, 1):
        print(f"\nRecommendation {i}:")
        print(f"Title: {book['Title']}")
        print(f"Authors: {book['Authors']}")
        print(f"Description: {book['Description']}")
else:
    print("\nNo book recommendations found.")
# Out:
# Which genre do you like to read? fantasy
# How many pages long are usually the books that you read? 300
# How old are you? 29
#
# Here are some book recommendations for you:
#
# Recommendation 1:
# Title: Peter Pan
# Authors: James Matthew Barrie
# Description: The adventures of the three darling children in Never-Never Land with Peter Pan, the boy who would not grow up.
#
# Recommendation 2:
# Title: Ficciones
# Authors: Jorge Luis Borges
# Description: Short narratives probe man's soul to reveal his conflicting emotions, motives, and desires and his tortured struggle for salvation
#
# Recommendation 3:
# Title: Through the Looking Glass
# Authors: Lewis Carroll
# Description: In this sequel to Alice in Wonderland, Alice climbs through a mirror in her room and enters a world similar to a chess board where she experiences many curious adventures with its fantastic inhabitants.
#
# Recommendation 4:
# Title: A Game of Thrones
# Authors: George R. R. Martin
# ...

# %%
import requests

def get_book_recommendations(genre, mood, favorite_authors, page_preference, recent_read):
    api_key = "AIzaSyAgnqAeOUBm47F9-blDN1znlMy_8vOmIPs"

    # Replace spaces in the genre with '+' for the query
    query_genre = genre.replace(' ', '+')

    # Construct the API request URL with additional parameters based on user preferences
    url = f"https://www.googleapis.com/books/v1/volumes?q=subject:{query_genre}&maxResults=5&key={api_key}"

    # Additional parameters based on user preferences
    if mood:
        url += f"&filter={mood.lower()}"
    if favorite_authors:
        url += f"&inauthor={favorite_authors.replace(' ', '+')}"
    if page_preference:
        url += f"&maxResults=5&printType=books&startIndex=0&maxAllowedMaturityRating=NOT_MATURE&projection=FULL&filter=free-ebooks"
    if recent_read:
        url += f"&intitle={recent_read.replace(' ', '+')}"

    # Make the API request
    response = requests.get(url)
    data = response.json()

    if 'items' in data:
        recommendations = []
        for item in data['items']:
            book_info = item['volumeInfo']
            title = book_info.get('title', 'Title not available')
            authors = ', '.join(book_info.get('authors', ['Author not available']))
            description = book_info.get('description', 'Description not available')

            recommendations.append({
                'Title': title,
                'Authors': authors,
                'Description': description
            })

        return recommendations
    else:
        return None

# Ask the user for input
genre = input("Which genre do you enjoy reading the most? ")
mood = input("What type of mood are you in when you read? ")
favorite_authors = input("Who are some of your favorite authors or books? ")
page_preference = input("Do you prefer shorter or longer books? ")
recent_read = input("Can you tell us about a book you recently enjoyed? What did you like about it? ")

# Get recommendations based on user input
recommendations = get_book_recommendations(genre, mood, favorite_authors, page_preference, recent_read)

# Display recommendations
if recommendations:
    print("\nHere are some book recommendations for you:")
    for i, book in enumerate(recommendations, 1):
        print(f"\nRecommendation {i}:")
        print(f"Title: {book['Title']}")
        print(f"Authors: {book['Authors']}")
        print(f"Description: {book['Description']}")
else:
    print("\nNo book recommendations found.")
# Out:
# Which genre do you enjoy reading the most? mystery
# What type of mood are you in when you read? adventure
# Who are some of your favorite authors or books?
# Do you prefer shorter or longer books? short
# Can you tell us about a book you recently enjoyed? What did you like about it?
#
# No book recommendations found.

# %%
import requests

def get_book_recommendations(genre, page_preference):
    api_key = "AIzaSyAgnqAeOUBm47F9-blDN1znlMy_8vOmIPs"

    # Replace spaces in the genre with '+' for the query
    query_genre = genre.replace(' ', '+')

    # Construct the API request URL with additional parameters based on user preferences
    url = f"https://www.googleapis.com/books/v1/volumes?q=subject:{query_genre}&maxResults=5&key={api_key}"

    # Additional parameters based on user preferences
    if page_preference:
        url += f"&maxResults=5&printType=books&startIndex=0&maxAllowedMaturityRating=NOT_MATURE&projection=FULL&filter=free-ebooks"

    # Make the API request
    response = requests.get(url)
    data = response.json()

    if 'items' in data:
        recommendations = []
        for item in data['items']:
            book_info = item['volumeInfo']
            title = book_info.get('title', 'Title not available')
            authors = ', '.join(book_info.get('authors', ['Author not available']))
            description = book_info.get('description', 'Description not available')

            recommendations.append({
                'Title': title,
                'Authors': authors,
                'Description': description
            })

        return recommendations
    else:
        return None

# Ask the user for input
genre = input("Which genre do you enjoy reading the most? ")
page_preference = input("Do you prefer shorter or longer books? ")

# Get recommendations based on user input
recommendations = get_book_recommendations(genre, page_preference)

# Display recommendations
if recommendations:
    print("\nHere are some book recommendations for you:")
    for i, book in enumerate(recommendations, 1):
        print(f"\nRecommendation {i}:")
        print(f"Title: {book['Title']}")
        print(f"Authors: {book['Authors']}")
        print(f"Description: {book['Description']}")
else:
    print("\nNo book recommendations found.")
# Out:
# Which genre do you enjoy reading the most? Fantasia
# Do you prefer shorter or longer books? longer
#
# No book recommendations found.
